# %%
# %pip install pycaret &> /dev/null
print("pycaret installed succesfully")
# Out:
# Note: you may need to restart the kernel to use updated packages.
# pycaret installed succesfully
# The syntax of the command is incorrect.

# %%
from pycaret.utils import version
version()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# d:\GLOBAL\model\pcrt.ipynb Cell 2 line 1
# ----> <a href='vscode-notebook-cell:/d%3A/GLOBAL/model/pcrt.ipynb#W1sZmlsZQ%3D%3D?line=0'>1</a> from pycaret.utils import version
#       <a href='vscode-notebook-cell:/d%3A/GLOBAL/model/pcrt.ipynb#W1sZmlsZQ%3D%3D?line=1'>2</a> version()
#
# ModuleNotFoundError: No module named 'pycaret'
# ...
#      ---------------------------------------- 0.0/14.6 MB ? eta -:--:--
#      ---------------------------------------- 0.0/14.6 MB ? eta -:--:--
#      ---------------------------------------- 0.0/14.6 MB ? eta -:--:--
#      --------------------------------------- 0.0/14.6 MB 262.6 kB/s eta 0:00:56
#      --------------------------------------- 0.0/14.6 MB 262.6 kB/s eta 0:00:56
#      --------------------------------------- 0.1/14.6 MB 456.6 kB/s eta 0:00:32
# ...
